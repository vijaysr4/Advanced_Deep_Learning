# %% [markdown]
# # Lab 7: Human motion generation
#
# ## Advanced deep learning

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Setup dataset

# %% [markdown]
# Please access this Google Drive folder: [link](https://drive.google.com/drive/folders/1V5yzlwBPSNVPj33SfDHnvMykXISh3CyB?usp=sharing) and create a shortcut in the root of your Google Drive `/content/drive/MyDrive/`.

# %%
from google.colab import drive
drive.mount('/content/drive')
# !ls /content/drive/MyDrive/humanml3d-data
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# caption_clip  caption_raw  checkpoints	humanml3d_test_split.txt  smplh  smpl_rifke

# %% [markdown]
# ### Setup environment

# %% [markdown]
# Make sure you're running on a T4 GPU Colab instance; if not, activate it.

# %%
# !nvidia-smi
# Out:
# Tue Mar  4 17:40:35 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# Clone the lab repository.

# %%
# !git clone https://github.com/robincourant/lab7-CSC52087EP.git
#!git clone https://github.com/robincourant/lab-MotionDiT.git
# Out:
# Cloning into 'lab7-CSC52087EP'...
# remote: Enumerating objects: 78, done.
# remote: Counting objects: 100% (78/78), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 78 (delta 5), reused 78 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (78/78), 1.64 MiB | 28.93 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# %cd lab7-CSC52087EP
#%cd lab-MotionDiT
# !ln -s /content/drive/MyDrive/humanml3d-data ./ # Plug the dataset in the repo
# Out:
# /content/lab7-CSC52087EP

# %% [markdown]
# Install required libraries

# %%
# !pip install hydra-core
# !pip install pyrender
# !pip install smplx
# !pip install torchtyping
# !pip install lightning
# !pip install ema_pytorch
# Out:
# Requirement already satisfied: hydra-core in /usr/local/lib/python3.11/dist-packages (1.3.2)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.11/dist-packages (from hydra-core) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from hydra-core) (4.9.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from hydra-core) (24.2)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from omegaconf<2.4,>=2.2->hydra-core) (6.0.2)
# Requirement already satisfied: pyrender in /usr/local/lib/python3.11/dist-packages (0.1.45)
# Requirement already satisfied: freetype-py in /usr/local/lib/python3.11/dist-packages (from pyrender) (2.5.1)
# Requirement already satisfied: imageio in /usr/local/lib/python3.11/dist-packages (from pyrender) (2.37.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from pyrender) (3.4.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pyrender) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from pyrender) (11.1.0)
# Requirement already satisfied: pyglet>=1.4.10 in /usr/local/lib/python3.11/dist-packages (from pyrender) (2.1.3)
# Requirement already satisfied: PyOpenGL==3.1.0 in /usr/local/lib/python3.11/dist-packages (from pyrender) (3.1.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pyrender) (1.13.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from pyrender) (1.17.0)
# Requirement already satisfied: trimesh in /usr/local/lib/python3.11/dist-packages (from pyrender) (4.6.4)
# Requirement already satisfied: smplx in /usr/local/lib/python3.11/dist-packages (0.1.28)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.11/dist-packages (from smplx) (1.26.4)
# Requirement already satisfied: torch>=1.0.1.post2 in /usr/local/lib/python3.11/dist-packages (from smplx) (2.5.1+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1.post2->smplx) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1.post2->smplx) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1.post2->smplx) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1.post2->smplx) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1.post2->smplx) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1.post2->smplx) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1.post2->smplx) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1.post2->smplx) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1.post2->smplx) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1.post2->smplx) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1.post2->smplx) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1.post2->smplx) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1.post2->smplx) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1.post2->smplx) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1.post2->smplx) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1.post2->smplx) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1.post2->smplx) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1.post2->smplx) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.1.post2->smplx) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.0.1.post2->smplx) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.0.1.post2->smplx) (3.0.2)
# Requirement already satisfied: torchtyping in /usr/local/lib/python3.11/dist-packages (0.1.5)
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from torchtyping) (2.5.1+cu124)
# Requirement already satisfied: typeguard<3,>=2.11.1 in /usr/local/lib/python3.11/dist-packages (from torchtyping) (2.13.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->torchtyping) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->torchtyping) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->torchtyping) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->torchtyping) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->torchtyping) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->torchtyping) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->torchtyping) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->torchtyping) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->torchtyping) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->torchtyping) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->torchtyping) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->torchtyping) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->torchtyping) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->torchtyping) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->torchtyping) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->torchtyping) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->torchtyping) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->torchtyping) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->torchtyping) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.7.0->torchtyping) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.7.0->torchtyping) (3.0.2)
# Requirement already satisfied: lightning in /usr/local/lib/python3.11/dist-packages (2.5.0.post0)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /usr/local/lib/python3.11/dist-packages (from lightning) (6.0.2)
# Requirement already satisfied: fsspec<2026.0,>=2022.5.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning) (2024.10.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from lightning) (0.13.0)
# Requirement already satisfied: packaging<25.0,>=20.0 in /usr/local/lib/python3.11/dist-packages (from lightning) (24.2)
# Requirement already satisfied: torch<4.0,>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from lightning) (2.5.1+cu124)
# Requirement already satisfied: torchmetrics<3.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from lightning) (1.6.2)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.11/dist-packages (from lightning) (4.67.1)
# Requirement already satisfied: typing-extensions<6.0,>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from lightning) (4.12.2)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.11/dist-packages (from lightning) (2.5.0.post0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning) (3.11.13)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities<2.0,>=0.10.0->lightning) (75.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (3.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<4.0,>=2.1.0->lightning) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<4.0,>=2.1.0->lightning) (1.3.0)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.11/dist-packages (from torchmetrics<3.0,>=0.7.0->lightning) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (1.18.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<4.0,>=2.1.0->lightning) (3.0.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning) (3.10)
# Requirement already satisfied: ema_pytorch in /usr/local/lib/python3.11/dist-packages (0.7.7)
# Requirement already satisfied: torch>=2.0 in /usr/local/lib/python3.11/dist-packages (from ema_pytorch) (2.5.1+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->ema_pytorch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->ema_pytorch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->ema_pytorch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->ema_pytorch) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->ema_pytorch) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->ema_pytorch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->ema_pytorch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->ema_pytorch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->ema_pytorch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->ema_pytorch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->ema_pytorch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->ema_pytorch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->ema_pytorch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->ema_pytorch) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->ema_pytorch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->ema_pytorch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->ema_pytorch) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->ema_pytorch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0->ema_pytorch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0->ema_pytorch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0->ema_pytorch) (3.0.2)

# %% [markdown]
# ## Human motion dataset and representation

# %% [markdown]
# ### HumanML3D dataset

# %% [markdown]
# #### Question 1: How many motions and descriptions are included in the HumanML3D dataset, and what are their average lengths?
# *Answer*
#
# It contains 14,616 motion sequences and 44,970 text descriptions. On average, each motion lasts around 3 - 3.5 seconds (roughly 200 frames at 60 fps), and each text description is about 15 words long.

# %% [markdown]
# ### SMPL representation

# %% [markdown]
# #### Question 2: What are the different input parameters of the SMPL model used to infer the vertices, and what do they represent?
# *Answer*
#
# The SMPL model uses:
#
# - ```betas: Optional[Tensor] = None``` Shape coefficients (typically 10 values) that determine the body's overall shape.
# - ```global_orient: Optional[Tensor] = None```
#  A 3D rotation (often in axis - angle form) that sets the overall body orientation.
# - ```body_pose: Optional[Tensor] = None``` Joint rotations (for 23 joints) that define the articulated pose.
# - ```transl: Optional[Tensor] = None``` A 3D vector that positions the body in space.

# %% [markdown]
# #### Code 2
# *Complete `visualize_smpl.py`*

# %%
# !HYDRA_FULL_ERROR=1 PYTHONPATH=$(pwd) python src/visualize_smpl.py

import moviepy.editor

moviepy.editor.ipython_display("./smpl.mp4")
# Out:
# [2025-03-04 17:42:24,954][numexpr.utils][INFO] - NumExpr defaulting to 2 threads.
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:44: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.feat_mean = torch.load(standardization["feat_rifke"]["mean_path"])
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:45: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.feat_std = torch.load(standardization["feat_rifke"]["std_path"])
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:46: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.tmrrifke_mean = torch.load(standardization["tmr_rifke"]["mean_path"])
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.tmrrifke_std = torch.load(standardization["tmr_rifke"]["std_path"])
# WARNING: You are using a SMPL+H model, with only 10 shape coefficients.
# Number of frames F: 197
# Number of features d: 205
#
# Caption:
# a man stands up, walks clock-wise in a circle, then sits back down.
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %% [markdown]
# ## Model architectures

# %% [markdown]
# ### Config A: Incontext

# %% [markdown]
# #### Code 3
# *Complete `src/models/modules/incontext.py`*

# %%
# !PYTHONPATH=$(pwd) python src/models/modules/incontext.py
# Out:
# Test passed!

# %% [markdown]
# ### Config B: AdaLN

# %% [markdown]
# #### Question 3:
# *Answer*
# Here is the AdaLN operation in LaTeX:
#
# $
# \operatorname{AdaLN}(x,\gamma,\beta) = \gamma \odot \frac{x - \mu(x)}{\sqrt{\sigma^2(x) + \epsilon}} + \beta
# $
#
# where:
# - $ \mu(x) $ is the mean of $ x $,
# - $ \sigma^2(x) $ is the variance of $ x $,
# - $ \epsilon $ is a small constant for numerical stability,
# - $ \gamma $ and $ \beta $ are the shift and scale parameters,
# - $ \odot $ denotes element-wise multiplication.

# %% [markdown]
# #### Code 4
# *Complete `src/models/modules/adaln.py`*

# %%
# !PYTHONPATH=$(pwd) python src/models/modules/adaln.py
# Out:
# Test passed!

# %% [markdown]
# ### Config C: Cross attention

# %% [markdown]
# #### Question 4:
# *Answer*
# Below is the cross-attention operation in LaTeX, where $ W_Q $, $ W_K $, and $ W_V $ are the query, key, and value projection matrices, respectively, and $ d $ is the token dimension:
#
# $
# \text{CA}(x,c) = \operatorname{softmax}\!\left(\frac{x\,W_Q\,(c\,W_K)^\top}{\sqrt{d}}\right) \,(c\,W_V)
# $
#
# In this expression:
# - $ x $ is the input token sequence,
# - $ c $ is the conditioning token sequence,
# - $ x\,W_Q $ computes the queries,
# - $ c\,W_K $ computes the keys,
# - $ c\,W_V $ computes the values,
# - The division by $\sqrt{d}$ scales the dot products for numerical stability, and
# - The softmax normalizes the attention scores before multiplying with the values.

# %% [markdown]
# #### Code 5
# *Complete `src/models/modules/cross attention.py`*

# %%
# !PYTHONPATH=$(pwd) python src/models/modules/cross_attention.py
# Out:
# Test passed!

# %% [markdown]
# #### Question 5:
# *Answer*
# AdaLN injects conditioning by directly modulating normalized features. It computes:
#
# $
# \operatorname{AdaLN}(x,\gamma,\beta) = \gamma \odot \frac{x - \mu(x)}{\sqrt{\sigma^2(x)+\epsilon}} + \beta,
# $
#
# where $\gamma$ and $\beta$ come from the conditioning signal. This means the conditioning continuously influences every layer without needing extra layers to compute queries, keys, and values as in cross-attention. As a result, AdaLN is more efficient and stable, using fewer parameters while ensuring consistent conditioning across layers.

# %% [markdown]
# ## Diffusion framework

# %% [markdown]
# ### DDPM

# %% [markdown]
# #### Code 6
# *Complete `src/training/losses/ddpm.py`*

# %%
# !PYTHONPATH=$(pwd) python src/training/losses/ddpm.py
# Out:
# Test passed!

# %% [markdown]
# #### Code 7
# *Complete `src/training/sampler/ddpm.py`*

# %%
# !PYTHONPATH=$(pwd) python src/generate.py batch_size=1 diffuser/sampler@diffuser.test_sampler=ddpm seed=2

import moviepy.editor
moviepy.editor.ipython_display("./generation_ddpm_incontext.mp4")
# Out:
# Seed set to 2
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# `Trainer(limit_predict_batches=1)` was configured so 1 batch will be used.
# /content/lab7-CSC52087EP/src/metrics/modules/tmr.py:132: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(motion_ckpt_path, map_location=self.device)
# /content/lab7-CSC52087EP/src/metrics/modules/tmr.py:140: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(text_ckpt_path, map_location=self.device)
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:44: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.feat_mean = torch.load(standardization["feat_rifke"]["mean_path"])
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:45: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.feat_std = torch.load(standardization["feat_rifke"]["std_path"])
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:46: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.tmrrifke_mean = torch.load(standardization["tmr_rifke"]["mean_path"])
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.tmrrifke_std = torch.load(standardization["tmr_rifke"]["std_path"])
# WARNING: You are using a SMPL+H model, with only 10 shape coefficients.
# /content/lab7-CSC52087EP/src/generate.py:31: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(config.checkpoint_path, map_location=torch.device("cpu"))
# 2025-03-04 20:38:12.100062: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741120692.120541   49800 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741120692.127082   49800 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-04 20:38:12.148563: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting DataLoader 0: 100% 1/1 [00:01<00:00,  1.33s/it]
#
# Caption:
# a man kicks something or someone with his left leg.
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %% [markdown]
# ### DDIM

# %% [markdown]
# #### Question 6:
# *Answer*
# #### DDPM Reverse Process (Markovian):
# $
# x_{t-1} \sim \mathcal{N}\Bigl(\mu_\theta(x_t, t),\, \Sigma_\theta(x_t, t)\Bigr)
# $
# In DDPM, the reverse process samples $x_{t-1}$ from a Gaussian distribution, where the mean $\mu_\theta(x_t, t)$ and covariance $\Sigma_\theta(x_t, t)$ are predicted by the model. This makes the process stochastic and Markovian, as each step depends only on the previous state $x_t$ and involves randomness.
#
#
# #### DDIM Reverse Process (Non-Markovian/Deterministic):
# $
# x_t = \sqrt{\bar{\alpha}_t}\, x_0 + \sqrt{1-\bar{\alpha}_t}\,\epsilon
# $
# Rearranging for a deterministic reverse mapping, DDIM uses:
# $
# x_{t-1} = \sqrt{\bar{\alpha}_{t-1}}\, x_0 + \sqrt{1-\bar{\alpha}_{t-1}}\,\epsilon,
# $
# which directly computes $x_{t-1}$ from the predicted clean sample $x_0$ and the noise $\epsilon$. This formulation is non-Markovian because it relies on the forward process's closed-form expression rather than sampling from a learned distribution at every step.
#
#
# DDPM samples $x_{t-1}$ via a Gaussian:
# $
# x_{t-1} \sim \mathcal{N}\Bigl(\mu_\theta(x_t, t),\, \Sigma_\theta(x_t, t)\Bigr),
# $
# introducing noise at each step, while DDIM computes a deterministic mapping:
# $
# x_{t-1} = \sqrt{\bar{\alpha}_{t-1}}\, x_0 + \sqrt{1-\bar{\alpha}_{t-1}}\,\epsilon,
# $
# which enables faster sampling by skipping intermediate stochastic steps.

# %% [markdown]
# #### Code 8
# *Complete `src/training/sampler/ddim.py`*

# %%
# !PYTHONPATH=$(pwd) python src/generate.py batch_size=1 diffuser/sampler@diffuser.test_sampler=ddim seed=3

import moviepy.editor
moviepy.editor.ipython_display("./generation_ddim_incontext.mp4")
# Out:
# Seed set to 3
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# `Trainer(limit_predict_batches=1)` was configured so 1 batch will be used.
# /content/lab7-CSC52087EP/src/metrics/modules/tmr.py:132: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(motion_ckpt_path, map_location=self.device)
# /content/lab7-CSC52087EP/src/metrics/modules/tmr.py:140: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(text_ckpt_path, map_location=self.device)
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:44: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.feat_mean = torch.load(standardization["feat_rifke"]["mean_path"])
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:45: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.feat_std = torch.load(standardization["feat_rifke"]["std_path"])
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:46: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.tmrrifke_mean = torch.load(standardization["tmr_rifke"]["mean_path"])
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.tmrrifke_std = torch.load(standardization["tmr_rifke"]["std_path"])
# WARNING: You are using a SMPL+H model, with only 10 shape coefficients.
# /content/lab7-CSC52087EP/src/generate.py:31: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(config.checkpoint_path, map_location=torch.device("cpu"))
# 2025-03-04 20:39:13.391239: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741120753.410613   50142 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741120753.417151   50142 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-04 20:39:13.438089: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting DataLoader 0: 100% 1/1 [00:01<00:00,  1.02s/it]
#
# Caption:
# a man kicks something or someone with his left leg.
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %% [markdown]
# #### Question 7:
# *Answer*
#
# Yes. DDPM adds random noise at every step, so it tends to produce more varied outputs. DDIM, on the other hand, can be made deterministic (or partially so), which can give sharper results but less variety.

# %% [markdown]
# ## Result analysis

# %% [markdown]
# ### Qualitative analysis

# %% [markdown]
# #### Code 9

# %%
# !PYTHONPATH=$(pwd) python src/generate.py batch_size=1 diffuser/network=incontext \
checkpoint_path=./humanml3d-data/checkpoints/incontext.ckpt

import moviepy.editor
moviepy.editor.ipython_display("./generation_ddpm_incontext.mp4")
# Out:
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# `Trainer(limit_predict_batches=1)` was configured so 1 batch will be used.
# /content/lab7-CSC52087EP/src/metrics/modules/tmr.py:132: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(motion_ckpt_path, map_location=self.device)
# /content/lab7-CSC52087EP/src/metrics/modules/tmr.py:140: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(text_ckpt_path, map_location=self.device)
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:44: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.feat_mean = torch.load(standardization["feat_rifke"]["mean_path"])
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:45: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.feat_std = torch.load(standardization["feat_rifke"]["std_path"])
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:46: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.tmrrifke_mean = torch.load(standardization["tmr_rifke"]["mean_path"])
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.tmrrifke_std = torch.load(standardization["tmr_rifke"]["std_path"])
# WARNING: You are using a SMPL+H model, with only 10 shape coefficients.
# /content/lab7-CSC52087EP/src/generate.py:31: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(config.checkpoint_path, map_location=torch.device("cpu"))
# 2025-03-04 20:40:15.493197: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741120815.513191   50476 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741120815.519633   50476 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-04 20:40:15.539924: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting DataLoader 0: 100% 1/1 [00:01<00:00,  1.43s/it]
#
# Caption:
# a man kicks something or someone with his left leg.
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
# !PYTHONPATH=$(pwd) python src/generate.py batch_size=1 diffuser/network=adaln \
checkpoint_path=./humanml3d-data/checkpoints/adaln.ckpt

import moviepy.editor
moviepy.editor.ipython_display("./generation_ddpm_adaln.mp4")
# Out:
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# `Trainer(limit_predict_batches=1)` was configured so 1 batch will be used.
# /content/lab7-CSC52087EP/src/metrics/modules/tmr.py:132: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(motion_ckpt_path, map_location=self.device)
# /content/lab7-CSC52087EP/src/metrics/modules/tmr.py:140: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(text_ckpt_path, map_location=self.device)
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:44: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.feat_mean = torch.load(standardization["feat_rifke"]["mean_path"])
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:45: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.feat_std = torch.load(standardization["feat_rifke"]["std_path"])
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:46: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.tmrrifke_mean = torch.load(standardization["tmr_rifke"]["mean_path"])
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.tmrrifke_std = torch.load(standardization["tmr_rifke"]["std_path"])
# WARNING: You are using a SMPL+H model, with only 10 shape coefficients.
# /content/lab7-CSC52087EP/src/generate.py:31: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(config.checkpoint_path, map_location=torch.device("cpu"))
# 2025-03-04 20:41:18.101799: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741120878.134595   50813 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741120878.143149   50813 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-04 20:41:18.175877: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting DataLoader 0: 100% 1/1 [00:01<00:00,  1.95s/it]
#
# Caption:
# a man kicks something or someone with his left leg.
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
# !PYTHONPATH=$(pwd) python src/generate.py batch_size=1 diffuser/network=cross_attention \
checkpoint_path=./humanml3d-data/checkpoints/cross_attention.ckpt

import moviepy.editor
moviepy.editor.ipython_display("./generation_ddpm_cross_attention.mp4")
# Out:
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# `Trainer(limit_predict_batches=1)` was configured so 1 batch will be used.
# /content/lab7-CSC52087EP/src/metrics/modules/tmr.py:132: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(motion_ckpt_path, map_location=self.device)
# /content/lab7-CSC52087EP/src/metrics/modules/tmr.py:140: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(text_ckpt_path, map_location=self.device)
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:44: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.feat_mean = torch.load(standardization["feat_rifke"]["mean_path"])
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:45: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.feat_std = torch.load(standardization["feat_rifke"]["std_path"])
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:46: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.tmrrifke_mean = torch.load(standardization["tmr_rifke"]["mean_path"])
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.tmrrifke_std = torch.load(standardization["tmr_rifke"]["std_path"])
# WARNING: You are using a SMPL+H model, with only 10 shape coefficients.
# /content/lab7-CSC52087EP/src/generate.py:31: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(config.checkpoint_path, map_location=torch.device("cpu"))
# 2025-03-04 20:42:21.770178: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741120941.789975   51154 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741120941.796067   51154 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-04 20:42:21.816042: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting DataLoader 0: 100% 1/1 [00:02<00:00,  2.05s/it]
#
# Caption:
# a man kicks something or someone with his left leg.
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %% [markdown]
# #### Question 8
# *Answer*
#
# Yes, there are clear qualitative differences. For the caption "a man kicks something or someone with his left leg":
#
# - The **InContext** model produces a motion with one clean, distinct kick.
# - The **AdaLN** model generates a motion with two kicks, suggesting a slight over-repetition.
# - The **Cross-Attention** model produces nearly three kicks but with noticeable noise and instability.
#
# This implies that the way conditioning is integrated (InContext vs. AdaLN vs. Cross-Attention) significantly affects the timing and clarity of the generated motions.

# %% [markdown]
# ### Quantitative analysis

# %% [markdown]
# #### Question 9:
# *Answer*
#
# The main assumption is that both the reference and generated feature spaces can be approximated as multivariate Gaussian distributions. This is important because it lets us compare two complex, high-dimensional distributions using only their first two moments—the mean and covariance.
#
# Mathematically, we assume:
#
# $
# \text{Reference features} \sim \mathcal{N}(\mu_r, \Sigma_r) \quad \text{and} \quad \text{Generated features} \sim \mathcal{N}(\mu_g, \Sigma_g).
# $
#
# Because of this Gaussian assumption, the Fréchet Distance (often used as the FID score) is given by the closed-form expression:
#
# $
# \text{FID} = \|\mu_r - \mu_g\|^2 + \operatorname{Tr}\Bigl(\Sigma_r + \Sigma_g - 2\bigl(\Sigma_r \Sigma_g\bigr)^{1/2}\Bigr).
# $
#
# **Reasoning with Math:**
#
# - **Moment Matching:** For Gaussian distributions, knowing the mean $\mu$ and covariance $\Sigma$ completely specifies the distribution. This means we only need to compare $\mu_r$ with $\mu_g$ and $\Sigma_r$ with $\Sigma_g$ to assess the similarity between the two distributions.
#
# - **2-Wasserstein Distance:** The closed-form for the squared 2-Wasserstein distance between two Gaussians is derived as:
#
#   $
#   W_2^2(\mathcal{N}(\mu_r,\Sigma_r),\mathcal{N}(\mu_g,\Sigma_g)) = \|\mu_r - \mu_g\|^2 + \operatorname{Tr}\left(\Sigma_r + \Sigma_g - 2\left(\Sigma_r^{1/2}\Sigma_g\Sigma_r^{1/2}\right)^{1/2}\right).
#   $
#
#   In practice, a simplified form is used, which is equivalent under the Gaussian assumption.
#
# - **Simplification:** By assuming Gaussianity, we avoid the need to compare every detail of the feature distributions. Instead, the difference between the two distributions is fully captured by differences in their means and covariances. This greatly simplifies the calculation and still provides a meaningful metric for evaluating the quality of generated samples.
#
# In summary, the Gaussian assumption reduces the complex problem of comparing high-dimensional distributions to a comparison of their means and covariances, which is why the Fréchet Distance can be computed efficiently in practice.

# %% [markdown]
# #### Code 10
# *Complete src/metrics/frechet.py*

# %% [markdown]
# #### Code 11
# *Complete src/metrics/similarity.py*

# %% [markdown]
# #### Code 12

# %% [markdown]
# #### Bonus 1:
# *Answer here*
#
# - **R1, R2, R3**: These check if the correct motion is in the top 1, 2, or 3 results for each text query.
# - **PRDC**: Precision, Recall, Density, and Coverage, which compare how well the generated motions match and cover the real motions, reflecting both quality (precision) and diversity (recall, density, coverage).

# %%
# !PYTHONPATH=$(pwd) python src/evaluate.py diffuser/network=incontext \
checkpoint_path=./humanml3d-data/checkpoints/incontext.ckpt
# Out:
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# `Trainer(limit_predict_batches=1)` was configured so 1 batch will be used.
# [2025-03-04 20:43:54,431][OpenGL.acceleratesupport][INFO] - No OpenGL_accelerate module loaded: No module named 'OpenGL_accelerate'
# /content/lab7-CSC52087EP/src/metrics/modules/tmr.py:132: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(motion_ckpt_path, map_location=self.device)
# /content/lab7-CSC52087EP/src/metrics/modules/tmr.py:140: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(text_ckpt_path, map_location=self.device)
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:44: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.feat_mean = torch.load(standardization["feat_rifke"]["mean_path"])
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:45: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.feat_std = torch.load(standardization["feat_rifke"]["std_path"])
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:46: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.tmrrifke_mean = torch.load(standardization["tmr_rifke"]["mean_path"])
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.tmrrifke_std = torch.load(standardization["tmr_rifke"]["std_path"])
# WARNING: You are using a SMPL+H model, with only 10 shape coefficients.
# /content/lab7-CSC52087EP/src/evaluate.py:35: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(config.checkpoint_path, map_location=torch.device("cpu"))
# 2025-03-04 20:43:57.858091: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741121037.878162   51634 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741121037.884593   51634 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-04 20:43:57.905163: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0:   0% 0/10 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/transformer.py:502: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. (Triggered internally at ../aten/src/ATen/NestedTensorImpl.cpp:178.)
#   output = torch._nested_tensor_from_mask(
# Testing DataLoader 0: 100% 10/10 [07:36<00:00, 45.61s/it]
# Metrics saved to generation_ddpm_incontext.csv
#
#       tmr/fid  tmr/tmr_score  tmr/precision  tmr/recall  tmr/density  tmr/coverage    tmr/R1    tmr/R2    tmr/R3
# 0  132.566574       0.587374       0.957813     0.83125     1.001563       0.88125  0.598437  0.748438  0.817187

# %%
# !PYTHONPATH=$(pwd) python src/evaluate.py diffuser/network=adaln \
checkpoint_path=./humanml3d-data/checkpoints/adaln.ckpt
# Out:
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# `Trainer(limit_predict_batches=1)` was configured so 1 batch will be used.
# [2025-03-04 20:51:46,201][OpenGL.acceleratesupport][INFO] - No OpenGL_accelerate module loaded: No module named 'OpenGL_accelerate'
# /content/lab7-CSC52087EP/src/metrics/modules/tmr.py:132: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(motion_ckpt_path, map_location=self.device)
# /content/lab7-CSC52087EP/src/metrics/modules/tmr.py:140: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(text_ckpt_path, map_location=self.device)
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:44: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.feat_mean = torch.load(standardization["feat_rifke"]["mean_path"])
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:45: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.feat_std = torch.load(standardization["feat_rifke"]["std_path"])
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:46: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.tmrrifke_mean = torch.load(standardization["tmr_rifke"]["mean_path"])
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.tmrrifke_std = torch.load(standardization["tmr_rifke"]["std_path"])
# WARNING: You are using a SMPL+H model, with only 10 shape coefficients.
# /content/lab7-CSC52087EP/src/evaluate.py:35: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(config.checkpoint_path, map_location=torch.device("cpu"))
# 2025-03-04 20:51:50.028868: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741121510.047973   53676 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741121510.054102   53676 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-04 20:51:50.075287: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0:   0% 0/10 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/transformer.py:502: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. (Triggered internally at ../aten/src/ATen/NestedTensorImpl.cpp:178.)
#   output = torch._nested_tensor_from_mask(
# Testing DataLoader 0: 100% 10/10 [07:56<00:00, 47.64s/it]
# Metrics saved to generation_ddpm_adaln.csv
#
#      tmr/fid  tmr/tmr_score  tmr/precision  tmr/recall  tmr/density  tmr/coverage    tmr/R1    tmr/R2    tmr/R3
# 0  54.663158       0.614126         0.9875     0.86875     1.102604      0.935938  0.595312  0.740625  0.804688

# %%
# !PYTHONPATH=$(pwd) python src/evaluate.py diffuser/network=cross_attention \
checkpoint_path=./humanml3d-data/checkpoints/cross_attention.ckpt
# Out:
# Seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# `Trainer(limit_predict_batches=1)` was configured so 1 batch will be used.
# [2025-03-04 20:59:58,925][OpenGL.acceleratesupport][INFO] - No OpenGL_accelerate module loaded: No module named 'OpenGL_accelerate'
# /content/lab7-CSC52087EP/src/metrics/modules/tmr.py:132: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(motion_ckpt_path, map_location=self.device)
# /content/lab7-CSC52087EP/src/metrics/modules/tmr.py:140: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(text_ckpt_path, map_location=self.device)
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:44: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.feat_mean = torch.load(standardization["feat_rifke"]["mean_path"])
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:45: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.feat_std = torch.load(standardization["feat_rifke"]["std_path"])
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:46: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.tmrrifke_mean = torch.load(standardization["tmr_rifke"]["mean_path"])
# /content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.tmrrifke_std = torch.load(standardization["tmr_rifke"]["std_path"])
# WARNING: You are using a SMPL+H model, with only 10 shape coefficients.
# /content/lab7-CSC52087EP/src/evaluate.py:35: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(config.checkpoint_path, map_location=torch.device("cpu"))
# 2025-03-04 21:00:02.586012: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741122002.605963   55807 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741122002.612366   55807 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-04 21:00:02.633495: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0:   0% 0/10 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/transformer.py:502: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. (Triggered internally at ../aten/src/ATen/NestedTensorImpl.cpp:178.)
#   output = torch._nested_tensor_from_mask(
# Testing DataLoader 0: 100% 10/10 [10:20<00:00, 62.02s/it]
# Metrics saved to generation_ddpm_cross_attention.csv
#
#      tmr/fid  tmr/tmr_score  tmr/precision  tmr/recall  tmr/density  tmr/coverage    tmr/R1    tmr/R2    tmr/R3
# 0  91.473007       0.648721       0.990625    0.839063     1.066146      0.920313  0.657812  0.809375  0.871875

# %% [markdown]
# #### Question 10:
# *Answer*
#
# Based on the metrics:
#
# - **Adaln**: With the lowest FID (54.66), it appears to produce the most realistic and natural motions.
# - **Cross-Attention**: Although its FID is higher (91.47), it scores best on TMR (0.6487) and retrieval (R1, R2, R3), suggesting superior alignment between the generated motions and the text descriptions.
# - **InContext**: With the highest FID (132.57) and lower retrieval scores, it seems to generate less natural motions with weaker text-motion coherence.
#
# The trade-off is: adaln excels in motion realism, while cross-attention better captures text-motion correspondence.

# %% [markdown]
# #### Bonus 2:
# *Answer*
#
# Using only 10 x 64 samples is a small evaluation set, so the metrics especially FDTMR, which depends on accurately estimating means and covariances can be noisy and unreliable. To improve reliability, we should use more samples, run multiple evaluations and average the results, and possibly report confidence intervals.

# %%
# !zip -r /content/project.zip /content/lab7-CSC52087EP -x "/content/lab7-CSC52087EP/humanml3d-data/*"
# Out:
#   adding: content/lab7-CSC52087EP/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lab7_CSC52087EP.pdf (deflated 29%)
#   adding: content/lab7-CSC52087EP/README.md (deflated 18%)
#   adding: content/lab7-CSC52087EP/generation_ddpm_adaln.mp4 (deflated 1%)
#   adding: content/lab7-CSC52087EP/generation_ddpm_cross_attention.mp4 (deflated 1%)
#   adding: content/lab7-CSC52087EP/configs/ (stored 0%)
#   adding: content/lab7-CSC52087EP/configs/dataset/ (stored 0%)
#   adding: content/lab7-CSC52087EP/configs/dataset/humanml3d.yaml (deflated 75%)
#   adding: content/lab7-CSC52087EP/configs/dataset/standardization/ (stored 0%)
#   adding: content/lab7-CSC52087EP/configs/dataset/standardization/tmr-rifke-std.pt (deflated 34%)
#   adding: content/lab7-CSC52087EP/configs/dataset/standardization/tmr-rifke-mean.pt (deflated 32%)
#   adding: content/lab7-CSC52087EP/configs/dataset/standardization/rifke-mean.pt (deflated 32%)
#   adding: content/lab7-CSC52087EP/configs/dataset/standardization/rifke-std.pt (deflated 35%)
#   adding: content/lab7-CSC52087EP/configs/config.yaml (deflated 49%)
#   adding: content/lab7-CSC52087EP/configs/diffuser/ (stored 0%)
#   adding: content/lab7-CSC52087EP/configs/diffuser/sampler/ (stored 0%)
#   adding: content/lab7-CSC52087EP/configs/diffuser/sampler/ddim.yaml (deflated 29%)
#   adding: content/lab7-CSC52087EP/configs/diffuser/sampler/ddpm.yaml (deflated 29%)
#   adding: content/lab7-CSC52087EP/configs/diffuser/metrics/ (stored 0%)
#   adding: content/lab7-CSC52087EP/configs/diffuser/metrics/tmr-rifke.yaml (deflated 57%)
#   adding: content/lab7-CSC52087EP/configs/diffuser/loss/ (stored 0%)
#   adding: content/lab7-CSC52087EP/configs/diffuser/loss/ddpm.yaml (deflated 29%)
#   adding: content/lab7-CSC52087EP/configs/diffuser/network/ (stored 0%)
#   adding: content/lab7-CSC52087EP/configs/diffuser/network/cross_attention.yaml (deflated 49%)
#   adding: content/lab7-CSC52087EP/configs/diffuser/network/incontext.yaml (deflated 48%)
#   adding: content/lab7-CSC52087EP/configs/diffuser/network/adaln.yaml (deflated 47%)
#   adding: content/lab7-CSC52087EP/configs/diffuser/dit_ddpm.yaml (deflated 46%)
#   adding: content/lab7-CSC52087EP/configs/compnode/ (stored 0%)
#   adding: content/lab7-CSC52087EP/configs/compnode/cpu.yaml (deflated 8%)
#   adding: content/lab7-CSC52087EP/configs/compnode/1g_1n.yaml (deflated 8%)
#   adding: content/lab7-CSC52087EP/results/ (stored 0%)
#   adding: content/lab7-CSC52087EP/results/ddpm-adaln-humanml3d/ (stored 0%)
#   adding: content/lab7-CSC52087EP/results/ddpm-adaln-humanml3d/2025-03-04-18-12-35/ (stored 0%)
#   adding: content/lab7-CSC52087EP/results/ddpm-adaln-humanml3d/2025-03-04-18-12-35/generate.log (stored 0%)
#   adding: content/lab7-CSC52087EP/results/ddpm-adaln-humanml3d/2025-03-04-18-12-35/.hydra/ (stored 0%)
#   adding: content/lab7-CSC52087EP/results/ddpm
)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-19-46-41/.hydra/hydra.yaml (deflated 65%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-20-43-54/ (stored 0%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-20-43-54/evaluate.log (deflated 24%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-20-43-54/.hydra/ (stored 0%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-20-43-54/.hydra/config.yaml (deflated 70%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-20-43-54/.hydra/overrides.yaml (deflated 15%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-20-43-54/.hydra/hydra.yaml (deflated 65%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-20-38-08/ (stored 0%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-20-38-08/generate.log (stored 0%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-20-38-08/.hydra/ (stored 0%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-20-38-08/.hydra/config.yaml (deflated 70%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-20-38-08/.hydra/overrides.yaml (deflated 16%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-20-38-08/.hydra/hydra.yaml (deflated 65%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-18-05-09/ (stored 0%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-18-05-09/generate.log (stored 0%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-18-05-09/.hydra/ (stored 0%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-18-05-09/.hydra/config.yaml (deflated 70%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-18-05-09/.hydra/overrides.yaml (deflated 15%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-18-05-09/.hydra/hydra.yaml (deflated 65%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-19-47-44/ (stored 0%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-19-47-44/generate.log (stored 0%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-19-47-44/.hydra/ (stored 0%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-19-47-44/.hydra/config.yaml (deflated 71%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-19-47-44/.hydra/overrides.yaml (deflated 16%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-19-47-44/.hydra/hydra.yaml (deflated 65%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-18-54-05/ (stored 0%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-18-54-05/generate.log (stored 0%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-18-54-05/.hydra/ (stored 0%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-18-54-05/.hydra/config.yaml (deflated 70%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-18-54-05/.hydra/overrides.yaml (deflated 16%)
#   adding: content/lab7-CSC52087EP/results/ddpm-incontext-humanml3d/2025-03-04-18-54-05/.hydra/hydra.yaml (deflated 65%)
#   adding: content/lab7-CSC52087EP/utils/ (stored 0%)
#   adding: content/lab7-CSC52087EP/utils/rendering_utils.py (deflated 72%)
#   adding: content/lab7-CSC52087EP/utils/rifke_utils.py (deflated 77%)
#   adding: content/lab7-CSC52087EP/utils/file_utils.py (deflated 69%)
#   adding: content/lab7-CSC52087EP/utils/rotation_utils.py (deflated 64%)
#   adding: content/lab7-CSC52087EP/utils/__pycache__/ (stored 0%)
#   adding: content/lab7-CSC52087EP/utils/__pycache__/file_utils.cpython-311.pyc (deflated 58%)
#   adding: content/lab7-CSC52087EP/utils/__pycache__/rifke_utils.cpython-311.pyc (deflated 51%)
#   adding: content/lab7-CSC52087EP/utils/__pycache__/random_utils.cpython-311.pyc (deflated 54%)
#   adding: content/lab7-CSC52087EP/utils/__pycache__/geometry_utils.cpython-311.pyc (deflated 64%)
#   adding: content/lab7-CSC52087EP/utils/__pycache__/rendering_utils.cpython-311.pyc (deflated 52%)
#   adding: content/lab7-CSC52087EP/utils/__pycache__/rotation_utils.cpython-311.pyc (deflated 53%)
#   adding: content/lab7-CSC52087EP/utils/geometry_utils.py (deflated 77%)
#   adding: content/lab7-CSC52087EP/utils/cam_marker.stl (deflated 66%)
#   adding: content/lab7-CSC52087EP/utils/random_utils.py (deflated 65%)
#   adding: content/lab7-CSC52087EP/utils/smpl.faces (deflated 64%)
#   adding: content/lab7-CSC52087EP/generation_ddpm_incontext.mp4 (deflated 2%)
#   adding: content/lab7-CSC52087EP/project.zip (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_38/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_38/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_38/events.out.tfevents.1741121040.dee7154a3e52.51634.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_10/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_10/events.out.tfevents.1741113798.dee7154a3e52.19101.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_10/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_14/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_14/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_14/events.out.tfevents.1741114637.dee7154a3e52.22931.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_26/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_26/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_26/events.out.tfevents.1741117669.dee7154a3e52.36553.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_0/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_0/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_0/events.out.tfevents.1741111415.dee7154a3e52.8264.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_19/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_19/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_19/events.out.tfevents.1741115049.dee7154a3e52.25050.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_36/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_36/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_36/events.out.tfevents.1741120880.dee7154a3e52.50813.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_16/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_16/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_16/events.out.tfevents.1741114863.dee7154a3e52.24054.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_11/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_11/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_11/events.out.tfevents.1741114450.dee7154a3e52.21927.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_7/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_7/events.out.tfevents.1741112054.dee7154a3e52.11497.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_7/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_8/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_8/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_8/events.out.tfevents.1741112339.dee7154a3e52.12829.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_37/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_37/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_37/events.out.tfevents.1741120944.dee7154a3e52.51154.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_1/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_1/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_1/events.out.tfevents.1741111515.dee7154a3e52.8845.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_3/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_3/events.out.tfevents.1741111696.dee7154a3e52.9753.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_3/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_15/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_15/events.out.tfevents.1741114701.dee7154a3e52.23275.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_15/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_22/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_22/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_22/events.out.tfevents.1741115653.dee7154a3e52.27780.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_29/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_29/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_29/events.out.tfevents.1741117857.dee7154a3e52.37559.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_28/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_28/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_28/events.out.tfevents.1741117794.dee7154a3e52.37227.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_4/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_4/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_4/events.out.tfevents.1741111758.dee7154a3e52.10095.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_23/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_23/events.out.tfevents.1741116155.dee7154a3e52.29913.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_23/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_33/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_33/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_33/events.out.tfevents.1741120694.dee7154a3e52.49800.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_32/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_32/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_32/events.out.tfevents.1741119746.dee7154a3e52.45704.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_20/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_20/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_20/events.out.tfevents.1741115112.dee7154a3e52.25384.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_34/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_34/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_34/events.out.tfevents.1741120756.dee7154a3e52.50142.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_13/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_13/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_13/events.out.tfevents.1741114576.dee7154a3e52.22606.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_5/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_5/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_5/events.out.tfevents.1741111897.dee7154a3e52.10763.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_17/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_17/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_17/events.out.tfevents.1741114925.dee7154a3e52.24387.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_6/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_6/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_6/events.out.tfevents.1741111975.dee7154a3e52.11092.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_39/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_39/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_39/events.out.tfevents.1741121512.dee7154a3e52.53676.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_35/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_35/events.out.tfevents.1741120817.dee7154a3e52.50476.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_35/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_27/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_27/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_27/events.out.tfevents.1741117732.dee7154a3e52.36894.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_30/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_30/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_30/events.out.tfevents.1741118773.dee7154a3e52.41519.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_25/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_25/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_25/events.out.tfevents.1741117607.dee7154a3e52.36216.0 (deflated 8%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_40/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_40/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_40/events.out.tfevents.1741122005.dee7154a3e52.55807.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_24/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_24/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_24/events.out.tfevents.1741116958.dee7154a3e52.33376.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_21/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_21/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_21/events.out.tfevents.1741115171.dee7154a3e52.25707.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_18/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_18/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_18/events.out.tfevents.1741114987.dee7154a3e52.24713.0 (deflated 8%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_12/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_12/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_12/events.out.tfevents.1741114513.dee7154a3e52.22264.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_31/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_31/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_31/events.out.tfevents.1741119245.dee7154a3e52.43551.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_2/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_2/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_2/events.out.tfevents.1741111608.dee7154a3e52.9314.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_9/ (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_9/hparams.yaml (stored 0%)
#   adding: content/lab7-CSC52087EP/lightning_logs/version_9/events.out.tfevents.1741113284.dee7154a3e52.16883.0 (deflated 9%)
#   adding: content/lab7-CSC52087EP/lab7_CSC52087EP.ipynb (deflated 83%)
#   adding: content/lab7-CSC52087EP/generation_ddim_incontext.mp4 (deflated 1%)
#   adding: content/lab7-CSC52087EP/generation_ddpm_cross_attention.csv (deflated 40%)
#   adding: content/lab7-CSC52087EP/src/ (stored 0%)
#   adding: content/lab7-CSC52087EP/src/metrics/ (stored 0%)
#   adding: content/lab7-CSC52087EP/src/metrics/modules/ (stored 0%)
#   adding: content/lab7-CSC52087EP/src/metrics/modules/tmr.py (deflated 69%)
#   adding: content/lab7-CSC52087EP/src/metrics/modules/__pycache__/ (stored 0%)
#   adding: content/lab7-CSC52087EP/src/metrics/modules/__pycache__/tmr.cpython-311.pyc (deflated 51%)
#   adding: content/lab7-CSC52087EP/src/metrics/motion_text.py (deflated 69%)
#   adding: content/lab7-CSC52087EP/src/metrics/__pycache__/ (stored 0%)
#   adding: content/lab7-CSC52087EP/src/metrics/__pycache__/prdc.cpython-311.pyc (deflated 58%)
#   adding: content/lab7-CSC52087EP/src/metrics/__pycache__/motion_text.cpython-311.pyc (deflated 47%)
#   adding: content/lab7-CSC52087EP/src/metrics/__pycache__/frechet.cpython-311.pyc (deflated 61%)
#   adding: content/lab7-CSC52087EP/src/metrics/__pycache__/similarity.cpython-311.pyc (deflated 48%)
#   adding: content/lab7-CSC52087EP/src/metrics/similarity.py (deflated 70%)
#   adding: content/lab7-CSC52087EP/src/metrics/prdc.py (deflated 73%)
#   adding: content/lab7-CSC52087EP/src/metrics/frechet.py (deflated 75%)
#   adding: content/lab7-CSC52087EP/src/visualize_smpl.py (deflated 55%)
#   adding: content/lab7-CSC52087EP/src/models/ (stored 0%)
#   adding: content/lab7-CSC52087EP/src/models/modules/ (stored 0%)
#   adding: content/lab7-CSC52087EP/src/models/modules/adaln.py (deflated 77%)
#   adding: content/lab7-CSC52087EP/src/models/modules/__pycache__/ (stored 0%)
#   adding: content/lab7-CSC52087EP/src/models/modules/__pycache__/adaln.cpython-311.pyc (deflated 53%)
#   adding: content/lab7-CSC52087EP/src/models/modules/__pycache__/incontext.cpython-311.pyc (deflated 47%)
#   adding: content/lab7-CSC52087EP/src/models/modules/__pycache__/base.cpython-311.pyc (deflated 57%)
#   adding: content/lab7-CSC52087EP/src/models/modules/__pycache__/cross_attention.cpython-311.pyc (deflated 53%)
#   adding: content/lab7-CSC52087EP/src/models/modules/incontext.py (deflated 75%)
#   adding: content/lab7-CSC52087EP/src/models/modules/cross_attention.py (deflated 80%)
#   adding: content/lab7-CSC52087EP/src/models/modules/base.py (deflated 77%)
#   adding: content/lab7-CSC52087EP/src/models/ddpm.py (deflated 65%)
#   adding: content/lab7-CSC52087EP/src/models/__pycache__/ (stored 0%)
#   adding: content/lab7-CSC52087EP/src/models/__pycache__/ddpm.cpython-311.pyc (deflated 42%)
#   adding: content/lab7-CSC52087EP/src/training/ (stored 0%)
#   adding: content/lab7-CSC52087EP/src/training/lr_schedulers/ (stored 0%)
#   adding: content/lab7-CSC52087EP/src/training/lr_schedulers/__pycache__/ (stored 0%)
#   adding: content/lab7-CSC52087EP/src/training/lr_schedulers/__pycache__/warmup_cosine.cpython-311.pyc (deflated 49%)
#   adding: content/lab7-CSC52087EP/src/training/lr_schedulers/warmup_cosine.py (deflated 67%)
#   adding: content/lab7-CSC52087EP/src/training/diffuser.py (deflated 77%)
#   adding: content/lab7-CSC52087EP/src/training/losses/ (stored 0%)
#   adding: content/lab7-CSC52087EP/src/training/losses/ddpm.py (deflated 66%)
#   adding: content/lab7-CSC52087EP/src/training/losses/__pycache__/ (stored 0%)
#   adding: content/lab7-CSC52087EP/src/training/losses/__pycache__/ddpm.cpython-311.pyc (deflated 45%)
#   adding: content/lab7-CSC52087EP/src/training/noise_schedulers/ (stored 0%)
#   adding: content/lab7-CSC52087EP/src/training/noise_schedulers/__pycache__/ (stored 0%)
#   adding: content/lab7-CSC52087EP/src/training/noise_schedulers/__pycache__/cosine.cpython-311.pyc (deflated 46%)
#   adding: content/lab7-CSC52087EP/src/training/noise_schedulers/cosine.py (deflated 63%)
#   adding: content/lab7-CSC52087EP/src/training/__pycache__/ (stored 0%)
#   adding: content/lab7-CSC52087EP/src/training/__pycache__/diffuser.cpython-311.pyc (deflated 55%)
#   adding: content/lab7-CSC52087EP/src/training/samplers/ (stored 0%)
#   adding: content/lab7-CSC52087EP/src/training/samplers/ddpm.py (deflated 66%)
#   adding: content/lab7-CSC52087EP/src/training/samplers/__pycache__/ (stored 0%)
#   adding: content/lab7-CSC52087EP/src/training/samplers/__pycache__/ddpm.cpython-311.pyc (deflated 45%)
#   adding: content/lab7-CSC52087EP/src/training/samplers/__pycache__/ddim.cpython-311.pyc (deflated 44%)
#   adding: content/lab7-CSC52087EP/src/training/samplers/ddim.py (deflated 66%)
#   adding: content/lab7-CSC52087EP/src/evaluate.py (deflated 64%)
#   adding: content/lab7-CSC52087EP/src/callbacks/ (stored 0%)
#   adding: content/lab7-CSC52087EP/src/callbacks/fix_nans.py (deflated 66%)
#   adding: content/lab7-CSC52087EP/src/callbacks/__pycache__/ (stored 0%)
#   adding: content/lab7-CSC52087EP/src/callbacks/__pycache__/metrics.cpython-311.pyc (deflated 54%)
#   adding: content/lab7-CSC52087EP/src/callbacks/metrics.py (deflated 76%)
#   adding: content/lab7-CSC52087EP/src/generate.py (deflated 59%)
#   adding: content/lab7-CSC52087EP/src/datasets/ (stored 0%)
#   adding: content/lab7-CSC52087EP/src/datasets/datamodule.py (deflated 80%)
#   adding: content/lab7-CSC52087EP/src/datasets/multimodal_dataset.py (deflated 74%)
#   adding: content/lab7-CSC52087EP/src/datasets/__pycache__/ (stored 0%)
#   adding: content/lab7-CSC52087EP/src/datasets/__pycache__/multimodal_dataset.cpython-311.pyc (deflated 50%)
#   adding: content/lab7-CSC52087EP/src/datasets/modalities/ (stored 0%)
#   adding: content/lab7-CSC52087EP/src/datasets/modalities/caption_dataset.py (deflated 70%)
#   adding: content/lab7-CSC52087EP/src/datasets/modalities/__pycache__/ (stored 0%)
#   adding: content/lab7-CSC52087EP/src/datasets/modalities/__pycache__/human_dataset.cpython-311.pyc (deflated 51%)
#   adding: content/lab7-CSC52087EP/src/datasets/modalities/__pycache__/caption_dataset.cpython-311.pyc (deflated 47%)
#   adding: content/lab7-CSC52087EP/src/datasets/modalities/human_dataset.py (deflated 73%)
#   adding: content/lab7-CSC52087EP/smpl.mp4 (deflated 1%)
#   adding: content/lab7-CSC52087EP/generation_ddpm_adaln.csv (deflated 36%)
#   adding: content/lab7-CSC52087EP/generation_ddpm_incontext.csv (deflated 41%)
#   adding: content/lab7-CSC52087EP/.git/ (stored 0%)
#   adding: content/lab7-CSC52087EP/.git/description (deflated 14%)
#   adding: content/lab7-CSC52087EP/.git/info/ (stored 0%)
#   adding: content/lab7-CSC52087EP/.git/info/exclude (deflated 28%)
#   adding: content/lab7-CSC52087EP/.git/branches/ (stored 0%)
#   adding: content/lab7-CSC52087EP/.git/index (deflated 50%)
#   adding: content/lab7-CSC52087EP/.git/config (deflated 30%)
#   adding: content/lab7-CSC52087EP/.git/hooks/ (stored 0%)
#   adding: content/lab7-CSC52087EP/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: content/lab7-CSC52087EP/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: content/lab7-CSC52087EP/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: content/lab7-CSC52087EP/.git/hooks/push-to-checkout.sample (deflated 55%)
#   adding: content/lab7-CSC52087EP/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: content/lab7-CSC52087EP/.git/hooks/pre-receive.sample (deflated 40%)
#   adding: content/lab7-CSC52087EP/.git/hooks/update.sample (deflated 68%)
#   adding: content/lab7-CSC52087EP/.git/hooks/pre-push.sample (deflated 49%)
#   adding: content/lab7-CSC52087EP/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: content/lab7-CSC52087EP/.git/hooks/pre-merge-commit.sample (deflated 39%)
#   adding: content/lab7-CSC52087EP/.git/hooks/pre-commit.sample (deflated 45%)
#   adding: content/lab7-CSC52087EP/.git/hooks/fsmonitor-watchman.sample (deflated 62%)
#   adding: content/lab7-CSC52087EP/.git/hooks/post-update.sample (deflated 27%)
#   adding: content/lab7-CSC52087EP/.git/HEAD (stored 0%)
#   adding: content/lab7-CSC52087EP/.git/objects/ (stored 0%)
#   adding: content/lab7-CSC52087EP/.git/objects/info/ (stored 0%)
#   adding: content/lab7-CSC52087EP/.git/objects/pack/ (stored 0%)
#   adding: content/lab7-CSC52087EP/.git/objects/pack/pack-4a073ec50f73c8eee6465aed87a0803f22820481.idx (deflated 26%)
#   adding: content/lab7-CSC52087EP/.git/objects/pack/pack-4a073ec50f73c8eee6465aed87a0803f22820481.pack (deflated 0%)
#   adding: content/lab7-CSC52087EP/.git/packed-refs (deflated 9%)
#   adding: content/lab7-CSC52087EP/.git/refs/ (stored 0%)
#   adding: content/lab7-CSC52087EP/.git/refs/tags/ (stored 0%)
#   adding: content/lab7-CSC52087EP/.git/refs/heads/ (stored 0%)
#   adding: content/lab7-CSC52087EP/.git/refs/heads/main (stored 0%)
#   adding: content/lab7-CSC52087EP/.git/refs/remotes/ (stored 0%)
#   adding: content/lab7-CSC52087EP/.git/refs/remotes/origin/ (stored 0%)
#   adding: content/lab7-CSC52087EP/.git/refs/remotes/origin/HEAD (stored 0%)
#   adding: content/lab7-CSC52087EP/.git/logs/ (stored 0%)
#   adding: content/lab7-CSC52087EP/.git/logs/HEAD (deflated 27%)
#   adding: content/lab7-CSC52087EP/.git/logs/refs/ (stored 0%)
#   adding: content/lab7-CSC52087EP/.git/logs/refs/heads/ (stored 0%)
#   adding: content/lab7-CSC52087EP/.git/logs/refs/heads/main (deflated 27%)
#   adding: content/lab7-CSC52087EP/.git/logs/refs/remotes/ (stored 0%)
#   adding: content/lab7-CSC52087EP/.git/logs/refs/remotes/origin/ (stored 0%)
#   adding: content/lab7-CSC52087EP/.git/logs/refs/remotes/origin/HEAD (deflated 27%)
#   adding: content/lab7-CSC52087EP/.gitignore (deflated 47%)
